# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
import matplotlib.pyplot as plt
import plotly.express as px
# %matplotlib inline

# %%
df = pd.read_csv('shinkansen.csv', thousands=',')

# %%
df
# Out:
#              Station_Name      Shinkansen_Line  Year Prefecture  \
# 0                   Tokyo   Tokaido_Shinkansen  1964      Tokyo
# 1               Shinagawa   Tokaido_Shinkansen  2003      Tokyo
# 2           Shin-Yokohama   Tokaido_Shinkansen  1964   Kanagawa
# 3                 Odawara   Tokaido_Shinkansen  1964   Kanagawa
# 4                   Atami   Tokaido_Shinkansen  1964   Shizuoka
# ..                    ...                  ...   ...        ...
# 103                Sendai    Kyushu_Shinkansen  2004  Kagoshima
# 104        Kagoshima-Chuo    Kyushu_Shinkansen  2004  Kagoshima
# 105   Okutsugaru-Imabetsu  Hokkaido_Shinkansen  2016     Aomori
# 106               Kikonai  Hokkaido_Shinkansen  2016   Hokkaido
# 107  Shin-Hakodate-Hokuto  Hokkaido_Shinkansen  2016   Hokkaido
#
#      Distance from Tokyo st      Company
# 0                       0.0   JR_Central
# 1                       6.8   JR_Central
# 2                      28.8   JR_Central
# ...

# %%
# updating the column value/data
df['Status'] = df['Year'].replace({df['Year']: df['Year'] - 1964})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-8007dccfddd6> in <module>
#       1 # updating the column value/data
# ----> 2 df['Status'] = df['Year'].replace({df['Year']: df['Year'] - 1964})
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __hash__(self)
#    1783
#    1784     def __hash__(self) -> int:
# -> 1785         raise TypeError(
#    1786             f"{repr(type(self).__name__)} objects are mutable, "
#    1787             f"thus they cannot be hashed"
#
# TypeError: 'Series' objects are mutable, thus they cannot be hashed

# %%
#change the size of the graph
sns.set(rc = {'figure.figsize':(60,40)})
ax = sns.barplot(x="Distance from Tokyo st", y="Year", data=df)
ax.axes.set_title("Title",fontsize=50)
ax.set_xlabel("Distance from Tokyo st",fontsize=30)
ax.set_ylabel("Year",fontsize=20)
# Out:
# Text(0, 0.5, 'Year')

# %%
#change the size of the graph
sns.set(rc = {'figure.figsize':(60,40)})
ax = sns.barplot(x="Year", y="Distance from Tokyo st", data=df)
ax.axes.set_title("Title",fontsize=50)
ax.set_xlabel("Year",fontsize=30)
ax.set_ylabel("Distance from Tokyo st",fontsize=20)
# Out:
# Text(0, 0.5, 'Distance from Tokyo st')

# %%
read_file = pd.read_csv ('shinkansen.csv')
read_file.to_excel ('shinkan.xlsx', index = None, header=True)

# %%
# Out:
#              Station_Name      Shinkansen_Line  Year Prefecture  \
# 0                   Tokyo   Tokaido_Shinkansen    64      Tokyo
# 1               Shinagawa   Tokaido_Shinkansen  2003      Tokyo
# 2           Shin-Yokohama   Tokaido_Shinkansen  1964   Kanagawa
# 3                 Odawara   Tokaido_Shinkansen  1964   Kanagawa
# 4                   Atami   Tokaido_Shinkansen  1964   Shizuoka
# ..                    ...                  ...   ...        ...
# 103                Sendai    Kyushu_Shinkansen  2004  Kagoshima
# 104        Kagoshima-Chuo    Kyushu_Shinkansen  2004  Kagoshima
# 105   Okutsugaru-Imabetsu  Hokkaido_Shinkansen  2016     Aomori
# 106               Kikonai  Hokkaido_Shinkansen  2016   Hokkaido
# 107  Shin-Hakodate-Hokuto  Hokkaido_Shinkansen  2016   Hokkaido
#
#      Distance from Tokyo st      Company
# 0                       0.0   JR_Central
# 1                       6.8   JR_Central
# 2                      28.8   JR_Central
# ...

# %% [markdown]
# https://www.geeksforgeeks.org/update-column-value-of-csv-in-python/
# https://medium.com/@siglimumuni/a-complete-guide-to-automating-excel-with-python-5d2a62cb2902
